# %% [markdown]
# ### 일률적으로 (Tumor) TLOD > 10 , (Dura) TLOD > 7.0 filter 했을 때

# %%
# 순서대로 clonal, subclonal, dura_private
facetcnv_190426_FFT = Clone ( "190426_FFT", "Dura", 49, "multiple", "Meningiomatosis", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )        
facetcnv_190426_PCT = Clone ( "190426_PCT", "Dura", 49, "multiple", "Meningiomatosis", "facetcnv", [0, 1], [2], [3], "Meningeal mosaicism" )        
facetcnv_190426_PFT = Clone ( "190426_PFT", "Dura", 49,  "multiple", "Meningiomatosis", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )        
facetcnv_190426_PP = Clone ( "190426_PP", "Dura", 49, "multiple", "Meningiomatosis", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )        
facetcnv_190426_PT = Clone ( "190426_PT", "Dura", 49, "multiple", "Meningiomatosis", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )        
facetcnv_230802_2 = Clone ( "230802_2", "Dura", 53, "solitary",  "Solitary", "facetcnv", [0], [], [1], "Meningeal mosaicism" )
facetcnv_230419 = Clone ( "230419", "Dura", 68, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
facetcnv_241023 = Clone ( "241023", "Dura", 42, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )          # Amplicon으로 rescue 된것
#facetcnv_220930_2 = Clone ( "220930_2", "Dura", 66, "solitary", "Solitary", "facetcnv", [0], [1, 2, 3], [4], "Meningeal mosaicism" )
facetcnv_221102 = Clone ( "221102", "Dura", 51, "solitary", "Solitary", "facetcnv", [0], [], [1], "Meningeal mosaicism" )         # Amplicon으로 rescue 된것
#facetcnv_240403_2 = Clone ( "240403_2", 48, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
facetcnv_240403_3 = Clone ( "240403_3", "Dura", 48, "solitary", "Solitary", "facetcnv", [0], [], [1], "Meningeal mosaicism" )    # Amplicon으로 rescue 된것
facetcnv_240412_2 = Clone ( "240412_2", "Dura", 44, "solitary", "Solitary", "facetcnv", [0], [], [1], "Meningeal mosaicism" )    # Amplicon으로 rescue 된것 
facetcnv_230127 = Clone ( "230127", "Dura", 51, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )     # Amplicon으로 rescue 된것
facetcnv_230526 = Clone ( "230526", "Dura", 65, "solitary",  "Solitary", "facetcnv", [0], [1], [2] , "Unshared" )  # PT.10 (SV)
facetcnv_190524 = Clone ( "190524", "Dura", 55, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" ) 
facetcnv_240320 = Clone ( "240320", "Dura", 67, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
facetcnv_231206 = Clone ( "231206", "Dura", 73, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Unshared" )    # PT.13 (Not shared)
facetcnv_231025 = Clone ( "231025", "Dura", 75, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )    # Amplicon으로 rescue 된것
facetcnv_230323_2 = Clone ( "230323_2", "Dura", 46, "multiple", "NF2", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
facetcnv_230323_11 = Clone ( "230323_11", "Dura", 46, "multiple", "NF2", "facetcnv", [0, 1, 2], [3], [5], "Meningeal mosaicism" )
facetcnv_230920 = Clone ( "230920", "Dura", 74, "multiple", "Meningiomatosis", "facetcnv", [0], [], [1], "Meningeal mosaicism" )
facetcnv_230822 = Clone ( "230822", "Dura", 82, "solitary" , "Solitary", "facetcnv", [0], [], [1] , "Meningeal mosaicism")
facetcnv_240325 = Clone ( "240325", "Dura", 51, "solitary", "Solitary", "facetcnv", [0], [], [1], "Unshared" )  # PT.18 (not shared)

# TRAF7 (+)
facetcnv_230405_2 = Clone ( "230405_2", "Dura", 68, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
facetcnv_230303_1 = Clone ( "230303_1", "Dura", 69, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Unshared" )
facetcnv_231006 = Clone ( "231006", "Dura", 51, "solitary", "Solitary", "facetcnv", [0, 1], [], [2], "Meningeal mosaicism" )     # AKT 1개가 shared
facetcnv_221202 = Clone ( "221202", "Dura", 67, "solitary", "Solitary", "facetcnv", [0], [1], [], "Meningeal mosaicism" )  # Amplicon으로 rescue 된것

# PC
facetcnv_220930_1 = Clone ( "220930_1", "Dura", 66, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" )
facetcnv_220930_2 = Clone ( "220930_2", "Dura", 66, "solitary", "Solitary", "facetcnv", [0], [1], [3], "Tumor infiltrated" )
facetcnv_220930_4 = Clone ( "220930_4", "Dura", 66, "solitary", "Solitary", "facetcnv", [0, 1], [2], [3], "Tumor infiltrated" )
facetcnv_221026 = Clone ( "221026", "Dura", 58, "solitary", "Solitary", "facetcnv", [1], [0, 2], [3, 4], "Tumor infiltrated" ) 
facetcnv_240110 = Clone ( "240110", "Dura", 58, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" )
facetcnv_241127 = Clone ( "241127", "Falx_1", 21, "multiple", "NF2", "facetcnv", [0, 1], [], [2], "Meningeal mosaicism"  ) 
facetcnv_241127_FT = Clone ( "241127_FT", "Falx_1", 21, "multiple", "NF2", "facetcnv", [0, 1], [], [], "Meningeal mosaicism"  ) 
facetcnv_241127_FTRt = Clone ( "241127_FTRt", "Falx_1", 21, "multiple", "NF2", "facetcnv", [0], [1], [2], "Meningeal mosaicism" ) 
facetcnv_241127_Para = Clone ( "241127_Para", "Falx_1", 21, "multiple", "NF2", "facetcnv", [0], [1], [2], "Meningeal m5osaicism" ) 
facetcnv_250207_Ant = Clone ( "250207_Ant", "Dura_Ant", 51, "multiple", "Meningiomatosis", "facetcnv", [0], [2], [3], "Tumor infiltrated" ) 
facetcnv_241016 = Clone ( "241016", "DT", 51, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" ) 
facetcnv_241211 = Clone ( "241211", "DT", 65, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" ) 
facetcnv_250425 = Clone ( "250425", "DT", 29, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" ) 
facetcnv_250212 = Clone ( "250212", "Falx", 51, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" ) 
facetcnv_250502 = Clone ( "250502", "DT", 45, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" ) 
facetcnv_250509 = Clone ( "250509", "DT", 56, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 순서대로 clonal, subclonal, dura_private
# ----> 2 facetcnv_190426_FFT = Clone ( "190426_FFT", "Dura", 49, "multiple", "Meningiomatosis", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
#       3 facetcnv_190426_PCT = Clone ( "190426_PCT", "Dura", 49, "multiple", "Meningiomatosis", "facetcnv", [0, 1], [2], [3], "Meningeal mosaicism" )
#       4 facetcnv_190426_PFT = Clone ( "190426_PFT", "Dura", 49,  "multiple", "Meningiomatosis", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
#
# NameError: name 'Clone' is not defined

# %% [markdown]
# ### (PC Tumor) TLOD > 12.0, (230419) TLOD >10.0 (나머지 Tumor) > 7.0 , (Dura) TLOD > 7.0 filter 했을 때

# %%
# if [[ "${TISSUE}" == *"Tumor"* ]]; then
#     if [[ "${Sample_ID}" == *"241016"* || "${Sample_ID}" == *"250212"* || "${Sample_ID}" == *"220930"* || "${Sample_ID}" == *"221026"* || "${Sample_ID}" == *"SMS"* ]]; then
#         TLOD_THRESHOLD="12.0"
#     elif [[ "${Sample_ID}" == *"230419"* ]]; then
#         TLOD_THRESHOLD="10.0"
#     else
#         TLOD_THRESHOLD="7.0"
#     fi
# else
#     TLOD_THRESHOLD="7.0"
# fi
# Out:
#   Cell In[3], line 1
#     if [[ "${TISSUE}" == *"Tumor"* ]]; then
#                          ^
# SyntaxError: invalid syntax

# %%
# 순서대로 clonal, subclonal, dura_private
facetcnv_190426_FFT = Clone ( "190426_FFT", "Dura", 49, "multiple", "Meningiomatosis", "facetcnv", [0 , 1], [2], [3], "Meningeal mosaicism" )        
facetcnv_190426_PCT = Clone ( "190426_PCT", "Dura", 49, "multiple", "Meningiomatosis", "facetcnv", [0, 1], [2], [3], "Meningeal mosaicism" )        
facetcnv_190426_PFT = Clone ( "190426_PFT", "Dura", 49,  "multiple", "Meningiomatosis", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )        
facetcnv_190426_PP = Clone ( "190426_PP", "Dura", 49, "multiple", "Meningiomatosis", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )        
facetcnv_190426_PT = Clone ( "190426_PT", "Dura", 49, "multiple", "Meningiomatosis", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )        
facetcnv_230802_2 = Clone ( "230802_2", "Dura", 53, "solitary",  "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
facetcnv_230419 = Clone ( "230419", "Dura", 68, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
facetcnv_241023 = Clone ( "241023", "Dura", 42, "solitary", "Solitary", "facetcnv", [0], [1, 2], [3], "Meningeal mosaicism" )          # Amplicon으로 rescue 된것
#facetcnv_220930_2 = Clone ( "220930_2", "Dura", 66, "solitary", "Solitary", "facetcnv", [0], [1, 2, 3], [4], "Meningeal mosaicism" )
facetcnv_221102 = Clone ( "221102", "Dura", 51, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )         # Amplicon으로 rescue 된것
#facetcnv_240403_2 = Clone ( "240403_2", 48, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
facetcnv_240403_3 = Clone ( "240403_3", "Dura", 48, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )    # Amplicon으로 rescue 된것
facetcnv_240412_2 = Clone ( "240412_2", "Dura", 44, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )    # Amplicon으로 rescue 된것 
facetcnv_230127 = Clone ( "230127", "Dura", 51, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )     # Amplicon으로 rescue 된것
facetcnv_230526 = Clone ( "230526", "Dura", 65, "solitary",  "Solitary", "facetcnv", [0], [1], [2] , "Unshared" )  # PT.10 (SV)
facetcnv_190524 = Clone ( "190524", "Dura", 55, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" ) 
facetcnv_240320 = Clone ( "240320", "Dura", 67, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
facetcnv_231206 = Clone ( "231206", "Dura", 73, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Unshared" )    # PT.13 (Not shared)
facetcnv_231025 = Clone ( "231025", "Dura", 75, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )    # Amplicon으로 rescue 된것
facetcnv_230323_2 = Clone ( "230323_2", "Dura", 46, "multiple", "NF2", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
facetcnv_230323_11 = Clone ( "230323_11", "Dura", 46, "multiple", "NF2", "facetcnv", [0, 1, 2], [3], [4], "Meningeal mosaicism" )
facetcnv_230920 = Clone ( "230920", "Dura", 74, "multiple", "Meningiomatosis", "facetcnv", [0], [], [1], "Meningeal mosaicism" )
facetcnv_230822 = Clone ( "230822", "Dura", 82, "solitary" , "Solitary", "facetcnv", [0], [], [1] , "Meningeal mosaicism")
facetcnv_240325 = Clone ( "240325", "Dura", 51, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Unshared" )  # PT.18 (not shared)

# TRAF7 (+)
facetcnv_230405_2 = Clone ( "230405_2", "Dura", 68, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Meningeal mosaicism" )
facetcnv_230303_1 = Clone ( "230303_1", "Dura", 69, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Unshared" )
facetcnv_231006 = Clone ( "231006", "Dura", 51, "solitary", "Solitary", "facetcnv", [0, 1], [2], [3], "Meningeal mosaicism" )     # AKT 1개가 shared
facetcnv_221202 = Clone ( "221202", "Dura", 67, "solitary", "Solitary", "facetcnv", [0], [1], [], "Meningeal mosaicism" )  # Amplicon으로 rescue 된것

# PC
facetcnv_220930_1 = Clone ( "220930_1", "Dura", 66, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" )
facetcnv_220930_2 = Clone ( "220930_2", "Dura", 66, "solitary", "Solitary", "facetcnv", [0], [2], [3], "Tumor infiltrated" )
facetcnv_220930_4 = Clone ( "220930_4", "Dura", 66, "solitary", "Solitary", "facetcnv", [0, 1], [2], [3], "Tumor infiltrated" )
facetcnv_221026 = Clone ( "221026", "Dura", 58, "solitary", "Solitary", "facetcnv", [0, 1, 2, 3], [4], [5], "Tumor infiltrated" ) 
facetcnv_240110 = Clone ( "240110", "Dura", 58, "solitary", "Solitary", "facetcnv", [0], [1, 2], [3], "Tumor infiltrated" )
facetcnv_241127 = Clone ( "241127", "Falx_1", 21, "multiple", "NF2", "facetcnv", [0], [1], [2], "Meningeal mosaicism"  ) 
facetcnv_241127_FT = Clone ( "241127_FT", "Falx_1", 21, "multiple", "NF2", "facetcnv", [1], [0], [], "Meningeal mosaicism"  ) 
facetcnv_241127_FTRt = Clone ( "241127_FTRt", "Falx_1", 21, "multiple", "NF2", "facetcnv", [0], [1], [2], "Meningeal mosaicism" ) 
facetcnv_241127_Para = Clone ( "241127_Para", "Falx_1", 21, "multiple", "NF2", "facetcnv", [0], [1], [2], "Meningeal m5osaicism" ) 
facetcnv_250207_Ant = Clone ( "250207_Ant", "Dura_Ant", 51, "multiple", "Meningiomatosis", "facetcnv", [0], [2], [3], "Tumor infiltrated" ) 
facetcnv_241016 = Clone ( "241016", "DT", 51, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" ) 
facetcnv_241211 = Clone ( "241211", "DT", 65, "solitary", "Solitary", "facetcnv", [0], [1], [], "Tumor infiltrated" ) 
facetcnv_250425 = Clone ( "250425", "DT", 29, "solitary", "Solitary", "facetcnv", [0], [1, 2], [], "Tumor infiltrated" ) 
facetcnv_250212 = Clone ( "250212", "Falx", 51, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" ) 
facetcnv_250502 = Clone ( "250502", "DT", 45, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" ) 
facetcnv_250509 = Clone ( "250509", "DT", 56, "solitary", "Solitary", "facetcnv", [0], [1], [2], "Tumor infiltrated" )
